# %% [markdown]
# <b>1. What is the result of the code, and explain?
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# print(X)
#
# &gt;&gt;&gt; func()

# %% [markdown]
# iNeuron

# %% [markdown]
# The global variable X is referred to from inside the function

# %% [markdown]
# <b>2. What is the result of the code, and explain?
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# X = &#39;NI!&#39;
#
# &gt;&gt;&gt; func()
# &gt;&gt;&gt; print(X)

# %% [markdown]
# iNeuron

# %% [markdown]
# 'X' inside the function comes under local scope which gets destroyed once the function is exited. Hence, print(X) prints the value of the global variable X

# %% [markdown]
# <b>3. What does this code print, and why?
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# X = &#39;NI&#39;
# print(X)
#
# &gt;&gt;&gt; func()
# &gt;&gt;&gt; print(X)

# %% [markdown]
# NI<br>
# iNeuron

# %% [markdown]
# The print(X) inside the function prints X in local scope. The print(X) outside the function prints X in global scope

# %% [markdown]
# <b>4. What output does this code produce? Why?
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# global X
# X = &#39;NI&#39;
#
# &gt;&gt;&gt; func()
# &gt;&gt;&gt; print(X)

# %% [markdown]
# NI<br>NI

# %% [markdown]
# Declaring global X inside the function makes the global variable X available in the local scope. Hence, assigning X ='NI' inside the function modifies the value of global variable.

# %% [markdown]
# <b>5. What about this code—what’s the output, and why?
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# X = &#39;NI&#39;
# def nested():
# print(X)
# nested()
#
# &gt;&gt;&gt; func()
# &gt;&gt;&gt; X

# %% [markdown]
# NI<br>
# iNeuron

# %% [markdown]
# Nested function refers to X='NI' in its parent function. X in the last line prints X in global scope

# %% [markdown]
# <b>6. How about this code: what is its output in Python 3, and explain?
#
# &gt;&gt;&gt; def func():
# X = &#39;NI&#39;
# def nested():
# nonlocal X
# X = &#39;Spam&#39;
# nested()
# print(X)
#
# &gt;&gt;&gt; func()

# %% [markdown]
# Spam

# %% [markdown]
# nonlocal X refers to X='NI' in the parent function and X='spam' modifies X in parent scope
